# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df = pd.read_csv('train (1).csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.price_range.value_counts()
# Out:
# 3    500
# 2    500
# 1    500
# 0    500
# Name: price_range, dtype: int64

# %%
X = df.drop('price_range',axis=1)
y = df['price_range']

# %%
#df1 = df[['battery_power', 'int_memory', 'mobile_wt', 'n_cores', 'px_height',
     #  'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time']]

# %%
#df2 = df['price_range']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Lr = LogisticRegression(max_iter=10000)

# %%
Lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
Lr.score(X_test,y_test)
# Out:
# 0.77

# %%
#param_grid = [{'panalty':['l1', 'l2', 'elasticnet', 'none'],
 #              'C':np.logspace(-4,4,20),
  #             'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
   #            'max_iter':[100,1000,2500,5000] 
    #          } 
     #        ]

# %%
#from sklearn.model_selection import GridSearchCV

# %%
#clf = GridSearchCV(Lr,param_grid=param_grid,cv=2,verbose=True,n_jobs=-1)

# %%
#clf_best = clf.fit(X_train,y_train)

# %%
y_pred = Lr.predict(X_test)

# %%
X_test.shape
# Out:
# (400, 20)

# %%
test.drop('id',axis=1,inplace=True)

# %%
y_pred1 = Lr.predict(test)

# %%
a = pd.DataFrame({'actual':y_test,'predicted':y_pred})

# %%
a.head(20)
# Out:
#       actual  predicted
# 1458       1          2
# 198        1          2
# 1276       2          2
# 1243       1          0
# 1267       1          1
# 201        1          0
# 903        2          2
# 295        1          1
# 1333       1          0
# 236        1          0
# 1842       0          0
# 1356       1          1
# 218        1          1
# 1406       1          0
# 1391       1          1
# 1412       0          1
# 1307       0          0
# 1499       2          1
# 423        0          0
# 1435       1          1

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
acc_logistic = accuracy_score(y_test,y_pred)

# %%
print('Classification Report:\n',classification_report(y_test,y_pred))
print('Confusion Matrix:\n',confusion_matrix(y_test,y_pred))
print('Training Score:',Lr.score(X_train,y_train))
print('Accuracy Score:',acc_logistic)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.84        94
#            1       0.69      0.67      0.68       102
#            2       0.76      0.73      0.75       120
#            3       0.80      0.87      0.83        84
#
#     accuracy                           0.77       400
#    macro avg       0.77      0.78      0.77       400
# weighted avg       0.77      0.77      0.77       400
#
# Confusion Matrix:
#  [[79 15  0  0]
#  [16 68 17  1]
#  [ 0 15 88 17]
#  [ 0  0 11 73]]
# Training Score: 0.794375
# Accuracy Score: 0.77

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(X_test,y_test)
# Out:
# 0.7975

# %%
y_pred = gnb.predict(X_test)

# %%
df_naiveGB = pd.DataFrame({'actual':y_test,'predicted':y_pred}) 
df_naiveGB.head(20)
# Out:
#       actual  predicted
# 1458       1          1
# 198        1          1
# 1276       2          2
# 1243       1          1
# 1267       1          1
# 201        1          1
# 903        2          2
# 295        1          1
# 1333       1          1
# 236        1          1
# 1842       0          0
# 1356       1          1
# 218        1          1
# 1406       1          1
# 1391       1          2
# 1412       0          0
# 1307       0          1
# 1499       2          1
# 423        0          0
# 1435       1          1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(X_test,y_test)
# Out:
# 0.8225

# %%
from sklearn.tree import plot_tree

# %%
fig = plt.figure(figsize=(25,20))
_ = plot_tree(dtc,
                   feature_names=X.columns,
                   class_names=['0','1','2','3'],
                   filled=True)

# %%
par_dict={'criterion':['gini','entropy'],
         'max_depth':range(1,10),
         'min_samples_split':range(1,10),
         'min_samples_leaf':range(1,5)}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(dtc,param_grid=par_dict,cv=10,verbose=1,n_jobs=1)
grid.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 6480 out of 6480 | elapsed:  2.0min finished
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 10),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 10)},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8}

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=3, min_samples_split=8)

# %%
grid.best_score_
# Out:
# 0.86

# %%
dtc2 = DecisionTreeClassifier(criterion='gini',max_depth=6, min_samples_leaf=4, min_samples_split=5)

# %%
dtc2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=4, min_samples_split=5)

# %%
dtc2.score(X_test,y_test)
# Out:
# 0.825

# %%
fig = plt.figure(figsize=(70,50))
_ = plot_tree(dtc2,
                   feature_names=X.columns,
                   class_names=['0','1','2','3'],
                   filled=True)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(X_test,y_test)
# Out:
# 0.8625

# %%
y_pred = rfc.predict(X_test)
df_random = pd.DataFrame({'actual':y_test,'predict':y_pred})
df_random.head(20)
# Out:
#       actual  predict
# 1458       1        1
# 198        1        1
# 1276       2        2
# 1243       1        1
# 1267       1        0
# 201        1        1
# 903        2        2
# 295        1        1
# 1333       1        1
# 236        1        1
# 1842       0        0
# 1356       1        1
# 218        1        1
# 1406       1        1
# 1391       1        1
# 1412       0        0
# 1307       0        1
# 1499       2        1
# 423        0        0
# 1435       1        0

# %%
from sklearn.svm import SVC

# %%
svm = SVC(kernel='linear')

# %%
svm.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
svm.score(X_test,y_test)
# Out:
# 0.965

# %%
support_vector_indices = svm.support_
print(support_vector_indices)
# Out:
# [ 252  379  455  711  748  979  986 1426 1561    8  113  270  330  404
#   503  560  568  581  725  728  948  953 1121 1143 1313 1381 1441 1513
#  1534   42   83  133  160  166  200  353  473  551  580  717  952  958
#   997 1136 1140 1239 1242 1276 1282 1363 1464 1469 1479 1496 1527  163
#   193  301  339  502  538  819  929  969 1216 1307 1343]

# %%
# Get number of support vectors per class
support_vectors_per_class = svm.n_support_
print(support_vectors_per_class)
# Out:
# [ 9 20 26 12]

# %%
y_pred_svm = svm.predict(X_test)
df_svm = pd.DataFrame({'actual':y_test,'predict':y_pred_svm})
df_svm.head(20)
# Out:
#       actual  predict
# 1458       1        1
# 198        1        1
# 1276       2        2
# 1243       1        1
# 1267       1        0
# 201        1        1
# 903        2        2
# 295        1        1
# 1333       1        1
# 236        1        1
# 1842       0        0
# 1356       1        1
# 218        1        1
# 1406       1        1
# 1391       1        1
# 1412       0        0
# 1307       0        0
# 1499       2        1
# 423        0        0
# 1435       1        1

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_test,y_test)
# Out:
# 0.9375

# %%
y_pred_knn = knn.predict(X_test)
df_knn = pd.DataFrame({'actual':y_test,'predict':y_pred_knn})
df_knn.head(20)
# Out:
#       actual  predict
# 1458       1        1
# 198        1        1
# 1276       2        2
# 1243       1        1
# 1267       1        0
# 201        1        1
# 903        2        2
# 295        1        1
# 1333       1        1
# 236        1        1
# 1842       0        0
# 1356       1        1
# 218        1        1
# 1406       1        1
# 1391       1        1
# 1412       0        0
# 1307       0        1
# 1499       2        2
# 423        0        1
# 1435       1        1

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
accuracy_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,X,y,cv=10)
    accuracy_rate.append(score.mean())

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,X,y,cv=10)
    error_rate.append(1-score.mean())

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
#plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
 #        markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(X)

# %%
X.shape
# Out:
# (2000, 20)

# %%
x_pca.shape
# Out:
# (2000, 2)

# %%
x_pca
# Out:
# array([[  430.5970944 ,  -795.78823104],
#        [  504.9847354 ,   696.62236757],
#        [  473.32982793,   763.94213631],
#        ...,
#        [  930.66926575,   436.67145174],
#        [-1252.73761513,  -629.8841122 ],
#        [ 1796.08152123,  -455.98743531]])

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=y)
plt.xlabel('First principle component')
plt.ylabel('Second principle component')
# Out:
# Text(0, 0.5, 'Second principle component')

# %%
pca.components_
# Out:
# array([[-3.47198014e-04,  1.21520201e-05,  2.63002912e-06,
#          1.89748044e-05,  6.05599727e-05,  3.40463135e-06,
#          5.48237530e-04, -2.53414241e-06, -8.44348497e-05,
#          1.03535536e-05,  1.62420234e-04, -9.90307368e-03,
#          9.64775480e-04,  9.99950255e-01,  6.12371435e-05,
#          1.42225196e-04,  5.46886920e-05,  6.25520198e-06,
#         -1.40798358e-05,  1.03583891e-05],
#        [ 1.03884008e-02, -2.47262901e-05, -2.08735861e-05,
#         -4.07785366e-06, -6.73320865e-05, -6.63424002e-06,
#          6.84761004e-05,  1.51519879e-05,  3.91158305e-05,
#          3.92449910e-05, -9.08839471e-05,  7.25036150e-01,
#          6.88601381e-01,  6.51958268e-03,  3.71862755e-04,
#          3.65603493e-04, -2.09044988e-05, -1.43530108e-05,
#          1.08600905e-05,  4.45371034e-05]])

# %%
df_pca = pd.DataFrame(pca.components_,columns=X.columns)

# %%
df_pca
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0      -0.000347  0.000012     0.000003  0.000019  0.000061  0.000003
# 1       0.010388 -0.000025    -0.000021 -0.000004 -0.000067 -0.000007
#
#    int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0    0.000548 -0.000003  -0.000084  0.000010  0.000162  -0.009903  0.000965
# 1    0.000068  0.000015   0.000039  0.000039 -0.000091   0.725036  0.688601
#
#        ram      sc_h      sc_w  talk_time   three_g  touch_screen      wifi
# 0  0.99995  0.000061  0.000142   0.000055  0.000006     -0.000014  0.000010
# 1  0.00652  0.000372  0.000366  -0.000021 -0.000014      0.000011  0.000045
